# %% [markdown]
# <a href="https://colab.research.google.com/github/Alkikaraja/Machine-Learning-Project/blob/main/Week_4/Project_Week_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# Menggunakan Tema dasar
sns.set_theme()

# Load Dataset
tips = sns.load_dataset("tips")

# Visualisasi data
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)

# %%
penguins = sns.load_dataset("penguins")
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")

# %%
sns.pairplot(data=penguins, hue="species")

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", col="region",
    hue="event", style="event",
)

# %%
sns.displot(data=tips, x="total_bill", col="time", kde=True)

# %%
sns.catplot(data=tips, kind="violin", x="day", y="total_bill", hue="smoker", split=True)

# %%
penguins = sns.load_dataset("penguins")
sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")

# %%
sns.displot(penguins, x="bill_length_mm", y="bill_depth_mm", hue="species", kind="kde")

# %%
#Regresi Model
anscombe = sns.load_dataset("anscombe")
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'I'"),
           ci=None, scatter_kws={"s": 80});

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'II'"),
           order=2, ci=None, scatter_kws={"s": 80});

# %% [markdown]
# Source :
#
# 1.   https://seaborn.pydata.org/introduction.html
# 2.   https://seaborn.pydata.org/tutorial/function_overview.html#similar-functions-for-similar-tasks
